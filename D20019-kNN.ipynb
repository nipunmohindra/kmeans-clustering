# %%
#importing relevant libraries
import numpy as np
import pandas as pd

# %%
#considering index to be zero initially
index=0

# %%
#importing the cars dataset from my system
cars = pd.read_csv(r"D:\Stu\PGP Data Science\Semester_1\IML\cars.csv")
cars
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1            Buick Skylark 320  15.0          8         350.0         165
# 2           Plymouth Satellite  18.0          8         318.0         150
# 3                AMC Rebel SST  16.0          8         304.0         150
# 4                  Ford Torino  17.0          8         302.0         140
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0          4         140.0          86
# 402          Volkswagen Pickup  44.0          4          97.0          52
# 403              Dodge Rampage  32.0          4         135.0          84
# 404                Ford Ranger  28.0          4         120.0          79
# 405                 Chevy S-10  31.0          4         119.0          82
#
#      Weight  Acceleration  Model  Origin
# ...

# %%
#finding first 5 values
cars.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %%
#Considering the particular variable we are interested in
cars2 = cars[["MPG","Cylinders","Weight","Horsepower"]]

# %%
#calling the data
cars2
# Out:
#       MPG  Cylinders  Weight  Horsepower
# 0    18.0          8    3504         130
# 1    15.0          8    3693         165
# 2    18.0          8    3436         150
# 3    16.0          8    3433         150
# 4    17.0          8    3449         140
# ..    ...        ...     ...         ...
# 401  27.0          4    2790          86
# 402  44.0          4    2130          52
# 403  32.0          4    2295          84
# 404  28.0          4    2625          79
# 405  31.0          4    2720          82
#
# [406 rows x 4 columns]

# %%
#top 5 values
cars2.head()
# Out:
#     MPG  Cylinders  Weight  Horsepower
# 0  18.0          8    3504         130
# 1  15.0          8    3693         165
# 2  18.0          8    3436         150
# 3  16.0          8    3433         150
# 4  17.0          8    3449         140

# %%
#dropping if any missing values
cars3=cars2.dropna()
cars3
# Out:
#       MPG  Cylinders  Weight  Horsepower
# 0    18.0          8    3504         130
# 1    15.0          8    3693         165
# 2    18.0          8    3436         150
# 3    16.0          8    3433         150
# 4    17.0          8    3449         140
# ..    ...        ...     ...         ...
# 401  27.0          4    2790          86
# 402  44.0          4    2130          52
# 403  32.0          4    2295          84
# 404  28.0          4    2625          79
# 405  31.0          4    2720          82
#
# [406 rows x 4 columns]

# %%
#zero values check
cars4=cars3.loc[(cars3!=0).any(1)]

# %%
cars4
# Out:
#       MPG  Cylinders  Weight  Horsepower
# 0    18.0          8    3504         130
# 1    15.0          8    3693         165
# 2    18.0          8    3436         150
# 3    16.0          8    3433         150
# 4    17.0          8    3449         140
# ..    ...        ...     ...         ...
# 401  27.0          4    2790          86
# 402  44.0          4    2130          52
# 403  32.0          4    2295          84
# 404  28.0          4    2625          79
# 405  31.0          4    2720          82
#
# [406 rows x 4 columns]

# %%
#calling the data
cars4
# Out:
#       MPG  Cylinders  Weight  Horsepower
# 0    18.0          8    3504         130
# 1    15.0          8    3693         165
# 2    18.0          8    3436         150
# 3    16.0          8    3433         150
# 4    17.0          8    3449         140
# ..    ...        ...     ...         ...
# 401  27.0          4    2790          86
# 402  44.0          4    2130          52
# 403  32.0          4    2295          84
# 404  28.0          4    2625          79
# 405  31.0          4    2720          82
#
# [406 rows x 4 columns]

# %%
#Now we remove all the zero values 
cars5=cars4[(cars4['MPG']>0) & (cars4['Horsepower']>0)]
cars5
# Out:
#       MPG  Cylinders  Weight  Horsepower
# 0    18.0          8    3504         130
# 1    15.0          8    3693         165
# 2    18.0          8    3436         150
# 3    16.0          8    3433         150
# 4    17.0          8    3449         140
# ..    ...        ...     ...         ...
# 401  27.0          4    2790          86
# 402  44.0          4    2130          52
# 403  32.0          4    2295          84
# 404  28.0          4    2625          79
# 405  31.0          4    2720          82
#
# [392 rows x 4 columns]

# %%
#top 5 values after 0 is removed
cars5.head()
# Out:
#     MPG  Cylinders  Weight  Horsepower
# 0  18.0          8    3504         130
# 1  15.0          8    3693         165
# 2  18.0          8    3436         150
# 3  16.0          8    3433         150
# 4  17.0          8    3449         140

# %%
# Now to standardize all the elements on cars 5 datatset we do the following
cars_sd=(cars5[['MPG','Cylinders','Weight','Horsepower']] - cars5[['MPG','Cylinders','Weight','Horsepower']].mean())/cars5[['MPG','Cylinders','Weight','Horsepower']].std()

# %%
#Our standardized dataset
cars_sd
# Out:
#           MPG  Cylinders    Weight  Horsepower
# 0   -0.697747   1.482053  0.619748    0.663285
# 1   -1.082115   1.482053  0.842258    1.572585
# 2   -0.697747   1.482053  0.539692    1.182885
# 3   -0.953992   1.482053  0.536160    1.182885
# 4   -0.825870   1.482053  0.554997    0.923085
# ..        ...        ...       ...         ...
# 401  0.455359  -0.862911 -0.220842   -0.479835
# 402  2.633448  -0.862911 -0.997859   -1.363154
# 403  1.095974  -0.862911 -0.803605   -0.531795
# 404  0.583482  -0.862911 -0.415097   -0.661694
# 405  0.967851  -0.862911 -0.303253   -0.583754
#
# [392 rows x 4 columns]

# %%
#calling top 5 values of standardized dataset
cars_sd.head()
# Out:
#         MPG  Cylinders    Weight  Horsepower
# 0 -0.697747   1.482053  0.619748    0.663285
# 1 -1.082115   1.482053  0.842258    1.572585
# 2 -0.697747   1.482053  0.539692    1.182885
# 3 -0.953992   1.482053  0.536160    1.182885
# 4 -0.825870   1.482053  0.554997    0.923085

# %%
#Defining train X
trainX = cars_sd.iloc[1:406, [1,2,3]]

# %%
#Calling trainX
trainX
# Out:
#      Cylinders    Weight  Horsepower
# 1     1.482053  0.842258    1.572585
# 2     1.482053  0.539692    1.182885
# 3     1.482053  0.536160    1.182885
# 4     1.482053  0.554997    0.923085
# 5     1.482053  1.605147    2.429924
# ..         ...       ...         ...
# 401  -0.862911 -0.220842   -0.479835
# 402  -0.862911 -0.997859   -1.363154
# 403  -0.862911 -0.803605   -0.531795
# 404  -0.862911 -0.415097   -0.661694
# 405  -0.862911 -0.303253   -0.583754
#
# [391 rows x 3 columns]

# %%
#top 5 values of trainX
trainX.head()
# Out:
#    Cylinders    Weight  Horsepower
# 1   1.482053  0.842258    1.572585
# 2   1.482053  0.539692    1.182885
# 3   1.482053  0.536160    1.182885
# 4   1.482053  0.554997    0.923085
# 5   1.482053  1.605147    2.429924

# %%
#defining and calling testX
testX = cars_sd.iloc[0,[1,2,3]]
testX
# Out:
# Cylinders     1.482053
# Weight        0.619748
# Horsepower    0.663285
# Name: 0, dtype: float64

# %%
#Defining and calling trainY
trainY = cars_sd.MPG[1:406]
trainY
# Out:
# 1     -1.082115
# 2     -0.697747
# 3     -0.953992
# 4     -0.825870
# 5     -1.082115
#          ...
# 401    0.455359
# 402    2.633448
# 403    1.095974
# 404    0.583482
# 405    0.967851
# Name: MPG, Length: 391, dtype: float64

# %%
#Top 5 values of trainY
trainY.head()
# Out:
# 1   -1.082115
# 2   -0.697747
# 3   -0.953992
# 4   -0.825870
# 5   -1.082115
# Name: MPG, dtype: float64

# %%
#Defining eucledian for distance calculation
def euclidean(p,q):
    d = 0

    for i in range(len(p)):
        d = d + (p[i]-q[i])**2

    return(np.sqrt(d))

# %%
#finding the distance  
dist = []

for i in range(len(trainX)):
    dist.append(euclidean(testX, trainX.iloc[i,[0,1,2]])) #taking0,1,2 because we have trainX and trainY as well
    
print(dist)
# Out:
# [0.9361283783412435, 0.5257309058046381, 0.5262803056787732, 0.26774752626520465, 2.022875424269271, 2.543340873917252, 2.404469839414072, 2.6957747766521623, 1.6111442735732133, 1.041518453702084, 0.7891419023649773, 0.6012735856406223, 2.5166816180508036, 2.846361595850412, 1.6809484349252748, 1.6877088032691239, 1.9766147180504845, 3.050596478228839, 3.7579576819823495, 2.7760223373637323, 2.8596406156999947, 2.8447096315235467, 2.815927512506145, 1.8628591951586237, 2.5665916107999416, 2.0883532645663396, 2.3212523779557834, 2.183810486958926, 3.050596478228839, 2.951262802742701, 2.9295704928603348, 1.741052688718737, 1.3425422810951981, 1.4228931703493588, 1.6192278333064454, 1.4306797102602375, 1.2311449446478542, 1.6260872802784982, 0.9709025742554446, 0.8693318489336055, 2.146054616894158, 1.793872088680331, 2.2531088923461167, 1.4324328077413597, 3.0715375477471305, 1.4319521368360124, 1.6583115283568914, 3.0150730845921463, 3.0368034254422, 3.280701972310132, 3.21513942577
# ...

# %%
#Now define the knn function
def knn(trainX,trainY,testX,k): 
    
    
    dist = []
    

    for i in range(0, len(trainX)):
        dist.append(euclidean(testX,trainX.iloc[i,[0,1,2]]))

    d = dist.copy()
    dist.sort()
    #print(d)

    index = []
    for i in range(0,k):
        indx = d.index(dist[i])
        index.append(indx)
        d[indx] = -1
        #print(d)
        
    #print(index)
    

    pred_y = np.mean(trainY.iloc[index])
    return(pred_y)

# %%
#Running knn for k=1
knn(trainX,trainY,testX,1)
# Out:
# -0.5439992690143953

# %%
#Running knn for k=2
knn(trainX,trainY,testX,2)
# Out:
# -0.4799378314231785

# %%
#Running knn for k=3
knn(trainX,trainY,testX,3)
# Out:
# -0.5696238440508821

# %%
#Running knn for k=4
knn(trainX,trainY,testX,4)
# Out:
# -0.633685281642099

# %%
#Running knn for k=5
knn(trainX,trainY,testX,5)
# Out:
# -0.610623164109261

# %%
#Running knn for k=6
knn(trainX,trainY,testX,6)
# Out:
# -0.7319128192819649

# %%
#Running knn for k=7
knn(trainX,trainY,testX,7)
# Out:
# -0.7453352157296484

# %%
#Running knn for k=8
knn(trainX,trainY,testX,8)
# Out:
# -0.7201682223902418

# %%
#Running knn for k=9
knn(trainX,trainY,testX,9)
# Out:
# -0.7148297692576404

# %%
#Running knn for k=10
knn(trainX,trainY,testX,10)
# Out:
# -0.7118402355033837
